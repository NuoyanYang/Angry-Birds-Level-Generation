# %% [markdown]
# ### Import packages

# %%
# Run below only if you are on Colab
# !pip install chainer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chainer
#   Downloading chainer-7.8.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from chainer) (67.6.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.9/dist-packages (from chainer) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from chainer) (3.10.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from chainer) (1.22.4)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from chainer) (3.19.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from chainer) (1.16.0)
# Building wheels for collected packages: chainer
#   Building wheel for chainer (setup.py) ... done
#   Created wheel for chainer: filename=chainer-7.8.1-py3-none-any.whl size=967735 sha256=203850eb91bf7b038381d9b2e612b731829f5ddc98ae3ed72dfa30a232b667ed
#   Stored in directory: /root/.cache/pip/wheels/83/90/84/57741aca5962d73dbeb37ee7a859d3cc31463273a133821071
# Successfully built chainer
# Installing collected packages: chainer
# Successfully installed chainer-7.8.1

# %%
import numpy as np
# If running on Colab, we need to specify the path of this notebook
import sys
if "google.colab" in sys.modules:
  # Set this to the directory of this file in Google Drive
  notebook_path = '/content/drive/MyDrive/CISC 455/light_weighted_gpu' 
  sys.path.append(notebook_path)
  from google.colab import files
  from google.colab import drive
  drive.mount('/content/drive')

from generator import fitness, generate

latent_size = 60
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Configurations:

# %%
file_path = "."
model_dir = "saved_models"

if "google.colab" in sys.modules:
  file_path = notebook_path

# %% [markdown]
# ### Create latent vectors:

# %%
latent_vec_list = []
    
for i in range(5):
    # Randomly create some mean and variance
    mean = np.random.uniform(2, 1, latent_size)
    var = np.random.uniform(2, 1, latent_size)

    # Multi-variate normal
    latent_vec = np.random.normal(0, 1, size=(1, latent_size))

    latent_vec_list.append(latent_vec)

# %% [markdown]
# ### Full call of `fitness()`:
# *   Return a list of tuples: (pig_counts, tnt_counts, material_types, object_types, object counts)
#
# <br>
#
# *   Material types(4) include:
#     *   "Wood"
#     *   "Stone"
#     *   "Ice"
#     *   "Basic Small": pig, tnt
#
# <br>
#
# *   Object types(21) include:
#     *   "TNT", "Pig",
#     *   "RectLong","RectLong90", (actually "RectFat" but the term is ambiguous)
#     *   "RectSmall","RectSmall90", "RectMedium","RectMedium90",
#     *   "RectBig", "RectBig90", "RectTiny", "RectTiny90",
#     *   "SquareSmall","SquareTiny","SquareHole",
#     *   "TriangleHole","TriangleHole90","Triangle", "Triangle90",
#     *   "Circle","CircleSmall"
#
#     <br>
#
#     *   Remark: "90" means aligned vertically.

# %%
fitness_list = fitness(latent_vecs = latent_vec_list, 
                       file_path = file_path, 
                       model_dir = model_dir)

for i in range(len(fitness_list)):
    print("Vector %d: pig count: %d, tnt count: %d, material types: %d, object types: %d, object count: %d" 
          % (i, fitness_list[i][0], fitness_list[i][1], fitness_list[i][2], fitness_list[i][3], fitness_list[i][4]))
# Out:
# 100%|██████████| 5/5 [00:08<00:00,  1.69s/it]
# Vector 0: pig count: 1, tnt count: 1, material types: 4, object types: 9, object count: 21
# Vector 1: pig count: 4, tnt count: 0, material types: 4, object types: 6, object count: 37
# Vector 2: pig count: 5, tnt count: 0, material types: 4, object types: 6, object count: 49
# Vector 3: pig count: 3, tnt count: 0, material types: 4, object types: 10, object count: 38
# Vector 4: pig count: 3, tnt count: 0, material types: 4, object types: 9, object count: 53

# %%
fitness_list
# Out:
# [[1, 1, 4, 9, 21],
#  [4, 0, 4, 6, 37],
#  [5, 0, 4, 6, 49],
#  [3, 0, 4, 10, 38],
#  [3, 0, 4, 9, 53]]

# %% [markdown]
# ### Full call of `generate()`:
# *   Generated levels are in "`file_path/generated_levels`".

# %%
generate(latent_vecs = latent_vec_list, repeat_times = 1, file_path = file_path, model_dir = model_dir)
# Out:
#  20%|██        | 1/5 [00:00<00:02,  1.75it/s]
# pig count: 1, tnt count: 1
#  40%|████      | 2/5 [00:01<00:01,  1.57it/s]
# pig count: 4, tnt count: 0
#  60%|██████    | 3/5 [00:01<00:01,  1.64it/s]
# pig count: 5, tnt count: 0
#  80%|████████  | 4/5 [00:02<00:00,  1.80it/s]
# pig count: 3, tnt count: 0
# 100%|██████████| 5/5 [00:02<00:00,  1.73it/s]
# pig count: 3, tnt count: 0
